# %% [markdown]
# Import Libraries

# %%
import os
import ee
import geemap

# %% [markdown]
# Create and customize the interactive map

# %%
Map = geemap.Map(center = (40, -100), zoom =4, lite_mode=True)
Map
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=KsXH3vQe0-80-KBgK-ghF7-zKsRDaB2afVa_cxSFM9A&tc=BiOxY3CIpeR0Ilrs9Mf0eQP9K0ql8NYpY0BtY62FUcM&cc=-XIMb92Uy86jPhKgrQm6zuxNlK7IsO0CO8K8ZKml25g>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=KsXH3vQe0-80-KBgK-ghF7-zKsRDaB2afVa_cxSFM9A&tc=BiOxY3CIpeR0Ilrs9Mf0eQP9K0ql8NYpY0BtY62FUcM&cc=-XIMb92Uy86jPhKgrQm6zuxNlK7IsO0CO8K8ZKml25g</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/geemap/common.py:225, in ee_initialize(token_name, auth_mode, service_account)
#     223                 copy_credentials_to_drive()
# --> 225     ee.Initialize(http_transport=httplib2.Http())
#     226 except Exception:
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/__init__.py:131, in Initialize(credentials, opt_url, cloud_api_key, http_transport, project)
#     130   credentials = data.get_persistent_credentials()
# --> 131 data.initialize(
#     132     credentials=credentials,
#     133     api_base_url=(opt_url + '/api' if opt_url else None),
#     134     tile_base_url=opt_url,
#     135     cloud_api_base_url=opt_url,
#     136     cloud_api_key=cloud_api_key,
#     137     project=project,
#     138     http_transport=http_transport)
#     139 # Initialize the dynamically loaded functions on the objects that want them.
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/data.py:202, in initialize(credentials, api_base_url, tile_base_url, cloud_api_base_url, cloud_api_key, project, http_transport)
#     200 _http_transport = http_transport
# --> 202 _install_cloud_api_resource()
#     204 if project is not None:
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/data.py:261, in _install_cloud_api_resource()
#     260 timeout = (_deadline_ms / 1000.0) or None
# --> 261 _cloud_api_resource = _cloud_api_utils.build_cloud_resource(
#     262     _cloud_api_base_url,
#     263     credentials=_credentials,
#     264     api_key=_cloud_api_key,
#     265     timeout=timeout,
#     266     headers_supplier=_make_request_headers,
#     267     response_inspector=_handle_profiling_response,
#     268     http_transport=_http_transport)
#     270 _cloud_api_resource_raw = _cloud_api_utils.build_cloud_resource(
#     271     _cloud_api_base_url,
#     272     credentials=_credentials,
#    (...)
#     277     http_transport=_http_transport,
#     278     raw=True)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/_cloud_api_utils.py:178, in build_cloud_resource(api_base_url, api_key, credentials, timeout, headers_supplier, response_inspector, http_transport, raw)
#     174 try:
#     175   # google-api-python-client made static_discovery the default in version 2,
#     176   # but it's not backward-compatible. There's no reliable way to check the
#     177   # package version, either.
# --> 178   resource = build(static_discovery=False)
#     179 except TypeError:
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/_cloud_api_utils.py:162, in build_cloud_resource.<locals>.build(**kwargs)
#     161 def build(**kwargs):
# --> 162   return discovery.build(
#     163       'earthengine',
#     164       VERSION,
#     165       discoveryServiceUrl=discovery_service_url,
#     166       developerKey=api_key,
#     167       http=http_transport,
#     168       requestBuilder=request_builder,
#     169       model=alt_model,
#     170       cache_discovery=False,
#     171       **kwargs)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/discovery.py:287, in build(serviceName, version, http, discoveryServiceUrl, developerKey, model, requestBuilder, credentials, cache_discovery, cache, client_options, adc_cert_path, adc_key_path, num_retries, static_discovery, always_use_jwt_access)
#     286 try:
# --> 287     content = _retrieve_discovery_doc(
#     288         requested_url,
#     289         discovery_http,
#     290         cache_discovery,
#     291         serviceName,
#     292         version,
#     293         cache,
#     294         developerKey,
#     295         num_retries=num_retries,
#     296         static_discovery=static_discovery,
#     297     )
#     298     service = build_from_document(
#     299         content,
#     300         base=discovery_url,
#    (...)
#     309         always_use_jwt_access=always_use_jwt_access,
#     310     )
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/discovery.py:422, in _retrieve_discovery_doc(url, http, cache_discovery, serviceName, version, cache, developerKey, num_retries, static_discovery)
#     421 req = HttpRequest(http, HttpRequest.null_postproc, actual_url)
# --> 422 resp, content = req.execute(num_retries=num_retries)
#     424 try:
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/google_auth_httplib2.py:209, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     207 request_headers = headers.copy() if headers is not None else {}
# --> 209 self.credentials.before_request(self._request, method, uri, request_headers)
#     211 # Check if the body is a file-like stream, and if so, save the body
#     212 # stream position so that it can be restored in case of refresh.
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/google/auth/credentials.py:135, in Credentials.before_request(self, request, method, url, headers)
#     134 if not self.valid:
# --> 135     self.refresh(request)
#     136 self.apply(headers)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/google/oauth2/credentials.py:335, in Credentials.refresh(self, request)
#     323     raise exceptions.RefreshError(
#     324         "The credentials do not contain the necessary fields need to "
#     325         "refresh the access token. You must specify refresh_token, "
#     326         "token_uri, client_id, and client_secret."
#     327     )
#     329 (
#     330     access_token,
#     331     refresh_token,
#     332     expiry,
#     333     grant_response,
#     334     rapt_token,
# --> 335 ) = reauth.refresh_grant(
#     336     request,
#     337     self._token_uri,
#     338     self._refresh_token,
#     339     self._client_id,
#     340     self._client_secret,
#     341     scopes=scopes,
#     342     rapt_token=self._rapt_token,
#     343     enable_reauth_refresh=self._enable_reauth_refresh,
#     344 )
#     346 self.token = access_token
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/google/oauth2/reauth.py:349, in refresh_grant(request, token_uri, refresh_token, client_id, client_secret, scopes, rapt_token, enable_reauth_refresh)
#     348 if not response_status_ok:
# --> 349     _client._handle_error_response(response_data, retryable_error)
#     350 return _client._handle_refresh_grant_response(response_data, refresh_token) + (
#     351     rapt_token,
#     352 )
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/google/oauth2/_client.py:69, in _handle_error_response(response_data, retryable_error)
#      67     error_details = json.dumps(response_data)
# ---> 69 raise exceptions.RefreshError(
#      70     error_details, response_data, retryable=retryable_error
#      71 )
#
# RefreshError: ('invalid_grant: Token has been expired or revoked.', {'error': 'invalid_grant', 'error_description': 'Token has been expired or revoked.'})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Map = geemap.Map(center = (40, -100), zoom =4, lite_mode=True)
#       2 Map
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/geemap/geemap.py:51, in Map.__init__(self, **kwargs)
#      48     kwargs["ee_initialize"] = True
#      50 if kwargs["ee_initialize"]:
# ---> 51     ee_initialize()
#      53 # Default map center location (lat, lon) and zoom level
#      54 latlon = [20, 0]
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/geemap/common.py:227, in ee_initialize(token_name, auth_mode, service_account)
#     225     ee.Initialize(http_transport=httplib2.Http())
#     226 except Exception:
# --> 227     ee.Authenticate(auth_mode=auth_mode)
#     228     ee.Initialize(http_transport=httplib2.Http())
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/__init__.py:103, in Authenticate(authorization_code, quiet, code_verifier, auth_mode, scopes)
#      77 def Authenticate(
#      78     authorization_code=None,
#      79     quiet=None,
#      80     code_verifier=None,
#      81     auth_mode=None,
#      82     scopes=None):
#      83   """Prompts the user to authorize access to Earth Engine via OAuth2.
#      84
#      85   Args:
#    (...)
#     101      (auth_url, code_verifier) when called with quiet='init_only'
#     102   """
# --> 103   return oauth.authenticate(authorization_code, quiet, code_verifier, auth_mode,
#     104                             scopes)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/oauth.py:408, in authenticate(cli_authorization_code, quiet, cli_code_verifier, auth_mode, scopes)
#     405 if flow.display_instructions(quiet):
#     406   _open_new_browser(flow.auth_url)
# --> 408 flow.save_code()
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/oauth.py:451, in Flow.save_code(self, code)
#     449   redirect_uri = self.server.url
#     450   code = self.server.fetch_code()  # Waits for oauth callback
# --> 451 _obtain_and_write_token(code, self.code_verifier, self.scopes, redirect_uri)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/oauth.py:188, in _obtain_and_write_token(auth_code, code_verifier, scopes, redirect_uri)
#     185   fetch_client = urllib.request.Request(FETCH_URL, data=data, headers=headers)
#     186   fetched_info = json.loads(
#     187       urllib.request.urlopen(fetch_client).read().decode())
# --> 188   client_info = {k: fetched_info[k] for k in ['client_id', 'client_secret']}
#     189   scopes = fetched_info.get('scopes') or scopes
#     190 token = request_token(auth_code.strip(), code_verifier, **client_info)
#
# File ~/opt/anaconda3/envs/geo/lib/python3.8/site-packages/ee/oauth.py:188, in <dictcomp>(.0)
#     185   fetch_client = urllib.request.Request(FETCH_URL, data=data, headers=headers)
#     186   fetched_info = json.loads(
#     187       urllib.request.urlopen(fetch_client).read().decode())
# --> 188   client_info = {k: fetched_info[k] for k in ['client_id', 'client_secret']}
#     189   scopes = fetched_info.get('scopes') or scopes
#     190 token = request_token(auth_code.strip(), code_verifier, **client_info)
#
# KeyError: 'client_id'

# %% [markdown]
# Add basemaps

# %%
Map = geemap.Map()
Map.add_basemap('HYBRID')
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
Map.add_basemap('OpenTopoMap')
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# Print first 5 basemaps

# %%
count = 0
for basemap in geemap.basemaps.keys():
    print(basemap)
    count += 1
    if count == 5:
        break
# Out:
# OpenStreetMap
# ROADMAP
# SATELLITE
# TERRAIN
# HYBRID

# %% [markdown]
# Add WMS and XYZ tile layers

# %%
Map = geemap.Map()

url = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}'
Map.add_tile_layer(url, name='Google Terrain', attribution='Google')
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
naip_url = 'https://services.nationalmap.gov/arcgis/services/USGSNAIPImagery/ImageServer/WMSServer?'
Map.add_wms_layer(
    url=naip_url, layers='0', name='NAIP Imagery', format='image/png', shown=True
)

# %% [markdown]
# Use drawing tools

# %%
#Draw any polygon on map using tool and get info here
#Map.user_roi.getInfo()

# %% [markdown]
# Convert GEE JavaScript to Python
# https://developers.google.com/earth-engine/guides/image_visualization

# %%
js_snippet = """
// Load an image.
var image = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_044034_20140318');

// Define the visualization parameters.
var vizParams = {
  bands: ['B5', 'B4', 'B3'],
  min: 0,
  max: 0.5,
  gamma: [0.95, 1.1, 1]
};

// Center the map and display the image.
Map.setCenter(-122.1899, 37.5010, 10); // San Francisco Bay
Map.addLayer(image, vizParams, 'false color composite');

"""

# %%
geemap.js_snippet_to_py(
    js_snippet, add_new_cell=True, import_ee=True, import_geemap=True, show_map=True
)

# %%
import ee
import geemap

Map = geemap.Map()

# Load an image.
image = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_044034_20140318')

# Define the visualization parameters.
vizParams = {
  'bands': ['B5', 'B4', 'B3'],
  'min': 0,
  'max': 0.5,
  'gamma': [0.95, 1.1, 1]
}

# Center the map and display the image.
Map.setCenter(-122.1899, 37.5010, 10); # San Francisco Bay
Map.addLayer(image, vizParams, 'False color composite')

Map
# Out:
# Map(center=[37.501, -122.1899], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(ch…

# %% [markdown]
# Earth Engine datasets

# %% [markdown]
# Load Earth Engine datasets¶

# %%
Map = geemap.Map()

# Add Earth Engine datasets
dem = ee.Image('USGS/SRTMGL1_003')
landcover = ee.Image("ESA/GLOBCOVER_L4_200901_200912_V2_3").select('landcover')
landsat7 = ee.Image('LANDSAT/LE7_TOA_5YEAR/1999_2003')
states = ee.FeatureCollection("TIGER/2018/States")

# Set visualization parameters.
vis_params = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}

# Add Earth Engine layers to Map
Map.addLayer(dem, vis_params, 'SRTM DEM', True, 0.5)
Map.addLayer(landcover, {}, 'Land cover')
Map.addLayer(
    landsat7,
    {'bands': ['B4', 'B3', 'B2'], 'min': 20, 'max': 200, 'gamma': 1.5},
    'Landsat 7',
)
Map.addLayer(states, {}, "US States")

Map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Map = geemap.Map()
#       3 # Add Earth Engine datasets
#       4 dem = ee.Image('USGS/SRTMGL1_003')
#
# NameError: name 'geemap' is not defined

# %% [markdown]
# Search the Earth Engine Data Catalog

# %%
Map = geemap.Map()
Map

# %%
dem = ee.Image('CGIAR/SRTM90_V4')
Map.addLayer(dem, {}, "CGIAR/SRTM90_V4")

# %%
vis_params = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}

Map.addLayer(dem, vis_params, "DEM")

# %% [markdown]
# Use the datasets module

# %%
from geemap.datasets import DATA

# %%
Map = geemap.Map()

dem = ee.Image(DATA.USGS_SRTMGL1_003)

vis_params = {
    'min': 0,
    'max': 4000,
    'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5'],
}

Map.addLayer(dem, vis_params, 'SRTM DEM')
Map
